# %%
import numpy as np
from matplotlib import pyplot as plt
import imageio
import os
from pathlib import Path
import random

# %%
video_dir = Path('videos/window-close-v2/train/0')
video_path = video_dir / random.choice(os.listdir(video_dir))
video = np.load(video_path)
plt.imshow(video[0][3])
plt.show()

# %%
imageio.mimwrite('videos/test.mp4', video[0], format='mp4', fps=24)
